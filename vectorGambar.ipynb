# %%
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing import image 
import matplotlib.pyplot as plt

# %%
blur = 'speakerResized.jpg'
nonblur = 'speakerBlur.jpg'

# %% [markdown]
# #### Image Blur

# %%
cwd = os.getcwd()
pathBlur = os.path.join(cwd, blur)

# %%
imgBlur = image.load_img(pathBlur)

# %%
new_width = 5
new_height = 5
dim = (new_width, new_height)

# %%
plt.imshow(imgBlur)

# %%
cv2.imread(pathBlur)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[252, 254, 254],
#         [252, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[252, 254, 254],
#         [252, 254, 254],
#         [254, 254, 254],
# ...

# %% [markdown]
# #### Non Blur

# %%
cwd = os.getcwd()
pathNonBlur = os.path.join(cwd, nonblur)

# %%
imgNonBlur = image.load_img(pathNonBlur)

# %%
plt.imshow(imgNonBlur)

# %%
cv2.imread(pathNonBlur)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
# ...

# %% [markdown]
# #### Kesimpulan

# %%
print(cv2.imread(pathNonBlur) == cv2.imread(pathBlur))
# Out:
# [[[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  ...
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...
#   [False False False]
#   [False False False]
#   [False False False]]
#
#  [[False False False]
#   [False False False]
#   [False False False]
#   ...
#   [False False False]
#   [False False False]
#   [False False False]]]
